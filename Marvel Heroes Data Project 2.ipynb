# %%
#Point 1 Import Required Libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display
print('Libraries Imported')
# Out:
# Libraries Imported

# %%
#Point 2 Retrieve Table from csv file
marvel = pd.read_csv(r"E:\Cognixia\charcters_stats.csv")

# %%
#Point 3 Show first 5 records from csv file
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
#Point 4 Show number of rows and columns in the table
marvel.shape
# Out:
# (611, 9)

# %%
#Point 5 Show the Alignment of the characters in the table
marvel['Alignment'].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
#Point 6 & 7 Show the Good Alignment characters in the table
good=marvel[marvel['Alignment']=='good']

# %%
good.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %%
#Point 8 Top 5 good alignment Character with higest speed
good.sort_values(by=['Speed'],ascending=False)[0:5]
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# 295     63      60    343
# 525    100      85    568
# 447     57      56    364

# %%
#Point 9 Show 5 records of super heroes who have maximum power of good alignment
good.sort_values(by=['Power'],ascending=False)[0:5]
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609        Zatanna      good            75        10     23          28
# 546           Thor      good            69       100     92         100
# 511          Spawn      good            75        60     50          90
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467

# %%
#Point 10 how many super heroes have maximum power of good alignment
good_max_power_count=good[good['Power']==100]

# %%
#Point 11 shape of point 10 
good_max_power_full.shape
# Out:
# (33, 9)

# %%
#Point 11 Show all records from point 10
good_max_power_full
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# ...

# %%
#Point 13 Retrieve total of first five records of max power of good alignment super heroes
good_strongest=good.sort_values(by=['Total'],ascending=False)[0:5]
good_strongest
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
#
#      Power  Combat  Total
# 361    100      85    581
# 537     94      85    579
# 525    100      85    568
# 546    100      85    546
# 536     85      75    544

# %%
#Point 14 graph of point 13
power=pd.DataFrame({'SuperHeroes':good_strongest['Name'],'Total_Powers':good_strongest['Total']})
sns.barplot(x="SuperHeroes",y="Total_Powers",data=power,color='#69b3a2')
plt.xticks(rotation=45,ha="right")
plt.show()
plt.savefig('Top_5_Strongest_SuperHeroes.png')

# %%
#Point 15 Show the Bad Alignment characters in the table
bad=marvel[marvel["Alignment"]=='bad']

# %%
#Point 16 Show the first 5 records of Bad Alignment characters in the table
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
#Point 17 Top 5 bad alignment character with highest speed
bad.sort_values(by=["Speed"],ascending=False)[0:5]
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610            Zoom       bad            50        10    100          28
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 610     72      28    288
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 242     94      95    579

# %%
#Point 18 Top 5 bad alignment character with highest intelligence
bad.sort_values(by=["Intelligence"],ascending=False)[0:5]
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 338       Lex Luthor       bad           100        10     12          14
# 336           Leader       bad           100        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
#
#      Power  Combat  Total
# 386    100      28    277
# 338     10      28    174
# 336     58      42    236
# 122     60      75    416
# 194     93      84    429

# %%
#Point 19 Top 5 strongest bad alignment characters based on total power
bad_strongest=bad.sort_values(by=["Total"],ascending=False)[0:5]
bad_strongest
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %%
power=pd.DataFrame({'SuperVillains':bad_strongest['Name'],'Total_Powers':bad_strongest['Total']})
sns.barplot(x="SuperVillains",y="Total_Powers",data=power,color='#69b3a2')
plt.xticks(rotation=45,ha="right")
plt.show()
plt.savefig('Top_5_Strongest_SuperVillains.png')

# %%
#Point 20 DISTRIBUTION OF SPEED graph
plt.figure(figsize=(10,8))
plt.hist(good["Speed"],color="purple")
plt.title("DISTRIBUTION OF SPEED for Super Heroes")
plt.xlabel("Speed")
plt.show()
plt.savefig('DISTRIBUTION_OF_SPEED.png')

# %%
#point 21 DISTRIBUTION OF COMBAT POWER for SuperVillains Graph
plt.figure(figsize=(10,8))
plt.hist(bad["Combat"],color="olive")
plt.title("DISTRIBUTION OF COMBAT POWER for Villains")
plt.xlabel("Combat Power")
plt.show()
plt.savefig('DISTRIBUTION_OF_COMBAT_POWER.png')
